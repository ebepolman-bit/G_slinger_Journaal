# %%
import numpy as np

def func_g(T,L):
    return (((2*np.pi)**2*L)/T**2)

Ltst= (0.614+1.07+124.5+1.275)/100
T_tst=(2.5+2.31+2.30+2.23+2.13)/5

128.4-4
print(func_g(T_tst,Ltst))
#radius = 2.55 / 2 = 1.275
T_tst_un= np.array([2.5,2.31,2.3,2.23,2.13])

np.std(T_tst_un)
N=10
T_tst2= (2.26+2.21+2.21+2.33+2.35+2.31+2.28+2.26+2.26+2.20)/N


T_tst2_unc= np.sqrt(0.25**2+0.25**2)/N
Ltst_unc= np.sqrt(3*(0.02/1000)**2 + (0.25/100)**2)

g=func_g(T_tst2,Ltst)

unc_g=np.sqrt(((func_g(T_tst2+T_tst2_unc,Ltst)-func_g(T_tst2-T_tst2_unc,Ltst))/2)**2+((func_g(T_tst2,Ltst+Ltst_unc)-func_g(T_tst2,Ltst-Ltst_unc))/2)**2)

print("g=",g,"+/-",unc_g)
